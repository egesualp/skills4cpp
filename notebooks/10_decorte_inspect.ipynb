# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/title_pairs_desc/decorte_master.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                   raw_title  \
# 0           0                   Line Cook
# 1           1                   Line Chef
# 2           2              Executive Chef
# 3           3  Banquet Cook 2( Lead Cook)
# 4           4          Kitchen Supervisor
#
#                                      raw_description          esco_title  \
# 0  - Prepped food for the line and cooked appetiz...                cook
# 1  - Prepared food for the kitchen and created sp...           head chef
# 2  - Promoted from rounds chef to sous chef in 20...           head chef
# 3  - Attended daily BEO meetings\n- Prepped and f...                cook
# 4  - Oversaw the am shift\n- Part of a renovation...  restaurant manager
#
#                                     esco_description  \
# 0  Cooks are culinary operatives who are able to ...
# 1  Head chefs manage the kitchen to oversee the p...
# 2  Head chefs manage the kitchen to oversee the p...
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0                    raw_title  \
# 7925         836  Intraday Operations Analyst
# 7926         837                   Consultant
# 7927         838   Workforce Specialist (WFM)
# 7928         839        Sr. Workforce Manager
# 7929         840   Workforce Planning Manager
#
#                                         raw_description  \
# 7925  Supervised a team responsible for intraday wor...
# 7926  Supervised operations and project implementati...
# 7927  Ensured optimum intraday staffing and performa...
# 7928  Reduced non-productive agent time by 33% for a...
# 7929  Managed a team of five workforce and Kronos an...
#
#                      esco_title  \
# 7925     call centre supervisor
# 7926   business service manager
# 7927  contact centre supervisor
# 7928     contact centre manager
# 7929        call centre manager
#
#                                        esco_description  \
# 7925  Call centre supervisors oversee call centre em...
# ...

# %%
df.iloc[7925, 2]
# Out:
# 'Supervised a team responsible for intraday workforce management operations. Chaired team meetings for quality work product. Reported daily metrics of help desk performance. Leveraged workforce on an intraday basis and adjusted manpower real-time. Co-created and co-chaired Values Committee and Stream University for workforce development and lower attrition.'

# %%
# Calculate text length statistics for raw_description
desc_lengths = df['raw_description'].str.len()

print("Raw Description Length Statistics:")
print(f"Mean: {desc_lengths.mean():.2f}")
print(f"Median: {desc_lengths.median():.2f}")
print(f"Min: {desc_lengths.min()}")
print(f"Max: {desc_lengths.max()}")
print(f"\nPercentiles:")
print(f"25th: {desc_lengths.quantile(0.25):.2f}")
print(f"50th: {desc_lengths.quantile(0.50):.2f}")
print(f"75th: {desc_lengths.quantile(0.75):.2f}")
print(f"90th: {desc_lengths.quantile(0.90):.2f}")
print(f"95th: {desc_lengths.quantile(0.95):.2f}")
print(f"99th: {desc_lengths.quantile(0.99):.2f}")
# Out:
# Raw Description Length Statistics:
# Mean: 515.38
# Median: 416.00
# Min: 13.0
# Max: 5043.0
#
# Percentiles:
# 25th: 267.00
# 50th: 416.00
# 75th: 641.00
# 90th: 950.00
# 95th: 1233.00
# 99th: 1978.95

# %%
from sentence_transformers import SentenceTransformer

# Load the model
model = SentenceTransformer('ElenaSenger/career-path-representation-mpnet-decorte')

# Get the max sequence length
max_seq_length = model.max_seq_length

print(f"Model: ElenaSenger/career-path-representation-mpnet-decorte")
print(f"Max sequence length: {max_seq_length} tokens")
print(f"\nNote: This is the maximum number of tokens the model can process.")
print(f"Texts longer than this will be truncated.")
# Out:
# Model: ElenaSenger/career-path-representation-mpnet-decorte
# Max sequence length: 384 tokens
#
# Note: This is the maximum number of tokens the model can process.
# Texts longer than this will be truncated.

# %%
import pandas as pd

# Path to the skills master CSV file
skills_path = "/dss/dssmcmlfs01/pr74ze/pr74ze-dss-0001/ra95kix2/results/karrierewege_esco_100k_esco_ground_truth/job_title_skills_master.csv"

# Load the data into a DataFrame
skills_df = pd.read_csv(skills_path)

print("Loaded job_title_skills_master.csv")
print(skills_df.head())
# Out:
# Loaded job_title_skills_master.csv
#    original_row_index    job_title              skill  score  \
# 0                   0  3d modeller       3D texturing    1.0
# 1                   0  3d modeller        3D lighting    1.0
# 2                   0  3d modeller  augmented reality    1.0
# 3                   0  3d modeller  computer graphics    1.0
# 4                   0  3d modeller         holography    1.0
#
#                                             skillUri
# 0  http://data.europa.eu/esco/skill/3e7516dc-0f7c...
# 1  http://data.europa.eu/esco/skill/6e53fd99-b646...
# 2  http://data.europa.eu/esco/skill/abdc7ac8-151f...
# 3  http://data.europa.eu/esco/skill/afda6ca0-7aa8...
# 4  http://data.europa.eu/esco/skill/fcb7ca53-130f...

# %%
import json

# Path to the fused scores JSON file
fused_scores_path = "/dss/dssmcmlfs01/pr74ze/pr74ze-dss-0001/ra95kix2/outputs/linear_fusion_sum/best_fused_scores.json"

# Load the JSON data
with open(fused_scores_path, "r") as f:
    fused_scores = json.load(f)

print("Loaded best_fused_scores.json")
print("Keys:", list(fused_scores.keys()))
if len(fused_scores) > 0:
    first_key = list(fused_scores.keys())[0]
    print(f"\nSample for first key '{first_key}':\n", fused_scores[first_key])
# Out:
# Loaded best_fused_scores.json
# Keys: ['metadata', 'scores']
#
# Sample for first key 'metadata':
#  {'fusion_mode': 'linear', 'aggregate': 'sum', 'top_k': 100, 'n_jobs': 7930, 'best_config_key': 'alpha0.20_T1.00_thres0.40', 'config': {'alpha': 0.2, 'temperature': 1.0, 'threshold': 0.4, 'map_full': 0.10541368526171582}}

# %%
len(fused_scores['scores'].keys())
# Out:
# 7930

# %%
import pandas as pd
df = pd.read_csv('/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/decorte_master.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                   raw_title  \
# 0           0                   Line Cook
# 1           1                   Line Chef
# 2           2              Executive Chef
# 3           3  Banquet Cook 2( Lead Cook)
# 4           4          Kitchen Supervisor
#
#                                      raw_description          esco_title  \
# 0  - Prepped food for the line and cooked appetiz...                cook
# 1  - Prepared food for the kitchen and created sp...           head chef
# 2  - Promoted from rounds chef to sous chef in 20...           head chef
# 3  - Attended daily BEO meetings\n- Prepped and f...                cook
# 4  - Oversaw the am shift\n- Part of a renovation...  restaurant manager
#
#                                     esco_description  \
# 0  Cooks are culinary operatives who are able to ...
# 1  Head chefs manage the kitchen to oversee the p...
# 2  Head chefs manage the kitchen to oversee the p...
# ...

# %%
df.job_id.describe()
# Out:
# count    7930.00000
# mean     3964.50000
# std      2289.33815
# min         0.00000
# 25%      1982.25000
# 50%      3964.50000
# 75%      5946.75000
# max      7929.00000
# Name: job_id, dtype: float64

# %%
import pickle

# Path to the test scores pickle file
test_scores_path = "/dss/dssmcmlfs01/pr74ze/pr74ze-dss-0001/ra95kix2/results/cpp/decorte_static/job_titles_desc/scores/test_scores_text.pkl"

# Load the test scores
with open(test_scores_path, "rb") as f:
    test_scores = pickle.load(f)

print("Loaded test_scores_text.pkl")
print("Type:", type(test_scores))
if hasattr(test_scores, "shape"):
    print("Shape:", test_scores.shape)
else:
    try:
        import numpy as np
        arr = np.array(test_scores)
        print("Converted to array, shape:", arr.shape)
    except Exception as e:
        print("Could not determine shape:", e)
# Out:
# Loaded test_scores_text.pkl
# Type: <class 'dict'>
# Converted to array, shape: ()

# %%
test_scores
# Out:
# {'scores': array([[ 0.03698274,  0.0494951 ,  0.05770375, ..., -0.01978263,
#           0.17990671,  0.04454451],
#         [ 0.08055464,  0.09808064,  0.09533575, ..., -0.00952173,
#           0.20232192,  0.0110376 ],
#         [ 0.07507903,  0.09368413,  0.0915006 , ..., -0.0133009 ,
#           0.1975559 ,  0.0143446 ],
#         ...,
#         [ 0.2127574 , -0.01866613, -0.09222065, ...,  0.10738701,
#          -0.09430698, -0.02769622],
#         [ 0.11017329,  0.07102193,  0.00059131, ...,  0.21999092,
#          -0.00515523, -0.02480993],
#         [ 0.1116991 ,  0.03320939, -0.02913485, ...,  0.20753339,
#          -0.02645975, -0.04009726]], shape=(1802, 1022), dtype=float32),
# ...

# %%
# inv

import pandas as pd
df = pd.read_csv('/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/decorte_master.csv')

# %%
from datasets import load_dataset

dataset = load_dataset("jensjorisdecorte/anonymous-working-histories")

# %%
def replace_esco_titles(example, i):
    """
    Replaces specific ESCO job titles with alternative titles for consistency.

    Args:
        example (dict): A dictionary representing a dataset row.
        i (int): The index of the ESCO title column.

    Returns:
        dict: Updated dictionary with the replaced ESCO title and URI.
    """
    replacements_title = {
        'ICT security engineer': 'cyber incident responder',
        'ict security engineer': 'cyber incident responder',
        'care at home worker': 'care home worker',
        'residential care home worker': 'care home worker',
        'ICT security manager': 'cybersecurity risk manager',
        'ict security manager': 'cybersecurity risk manager',
        'care at home worker': 'care home worker',
        'handyman': 'handyperson',
        'corporate banking manager': 'corporate banking adviser',
    }

    original_title = example[f'ESCO_title_{i}']
    if not pd.isna(original_title):
        processed_title = original_title.strip().lower()
        final_title = replacements_title.get(processed_title, processed_title)
    else:
        final_title = original_title

    example[f'ESCO_title_{i}'] = final_title

    replacements_uri = {
        'http://data.europa.eu/esco/occupation/81309031-dad2-4a7a-bde6-7f6e518f89ff': 
        'http://data.europa.eu/esco/occupation/f4525ed8-54eb-4a3b-90db-55cc01b0d9fd'
    }
    
    example[f'ESCO_uri_{i}'] = replacements_uri.get(example[f'ESCO_uri_{i}'], example[f'ESCO_uri_{i}'])
    
    return example

# %%
import pandas as pd
df_occ = pd.read_csv(r'../data/esco_datasets/occupations_en.csv')

# %%
df_skill_rel = pd.read_csv(r'../data/esco_datasets/occupationSkillRelations_en.csv')

# %%
df_occ['iscoGroup_1'] = df_occ.iscoGroup.astype(str).apply(lambda x: x[:1]).astype(int)
df_occ['iscoGroup_2'] = df_occ.iscoGroup.astype(str).apply(lambda x: x[:2]).astype(int)
df_occ['iscoGroup_3'] = df_occ.iscoGroup.astype(str).apply(lambda x: x[:3]).astype(int)
df_occ['iscoGroup_4'] = df_occ.iscoGroup.astype(str).apply(lambda x: x[:4]).astype(int)

# %%
df_occ['iscoGroup_1'] = df_occ['code'].astype(str).str[0]
df_occ['iscoGroup_2'] = df_occ['code'].astype(str).str[:2]
df_occ['iscoGroup_3'] = df_occ['code'].astype(str).str[:3]
df_occ['iscoGroup_4'] = df_occ['code'].astype(str).str[:4]

# %%
df_occ.merge(df_skill_rel, left_on='conceptUri', right_on='occupationUri', how='inner').groupby(
    'iscoGroup_2'
).skillUri.nunique().describe()
# Out:
# count      42.000000
# mean      954.119048
# std       832.530061
# min        56.000000
# 25%       351.750000
# 50%       705.000000
# 75%      1469.750000
# max      3596.000000
# Name: skillUri, dtype: float64

# %%
df_occ.merge(df_skill_rel, left_on='conceptUri', right_on='occupationUri', how='inner').groupby(
    'iscoGroup_3'
).skillUri.nunique().describe()
# Out:
# count     125.000000
# mean      400.336000
# std       339.386803
# min        16.000000
# 25%       184.000000
# 50%       320.000000
# 75%       519.000000
# max      2179.000000
# Name: skillUri, dtype: float64

# %%
df_occ.merge(df_skill_rel, left_on='conceptUri', right_on='occupationUri', how='inner').groupby(
    'iscoGroup_1'
).skillUri.nunique().describe()
# Out:
# count       9.0000
# mean     3325.0000
# std      2319.4003
# min       755.0000
# 25%      1361.0000
# 50%      3116.0000
# 75%      3708.0000
# max      7549.0000
# Name: skillUri, dtype: float64

# %%
df_occ.iscoGroup.nunique()
# Out:
# 426

# %%
df_occ[df_occ.preferredLabel.str.lower() == "care home worker"]
# Out:
#      conceptType                                         conceptUri  \
# 2899  Occupation  http://data.europa.eu/esco/occupation/f4525ed8...
#
#       iscoGroup    preferredLabel  \
# 2899       3412  care home worker
#
#                                               altLabels hiddenLabels  \
# 2899  community home care worker\nhome care assistan...          NaN
#
#         status              modifiedDate  \
# 2899  released  2022-12-22T15:04:36.328Z
#
#                                 regulatedProfessionNote scopeNote definition  \
# 2899  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
#
#                                                inScheme  \
# 2899  http://data.europa.eu/esco/concept-scheme/memb...
#
#                                             description      code
# 2899  Care home workers provide domiciliary services...  3412.4.2

# %%
df_occ[df_occ.conceptUri.str.lower() == "http://data.europa.eu/esco/occupation/f4525ed8-54eb-4a3b-90db-55cc01b0d9fd"]
# Out:
#      conceptType                                         conceptUri  \
# 2899  Occupation  http://data.europa.eu/esco/occupation/f4525ed8...
#
#       iscoGroup    preferredLabel  \
# 2899       3412  care home worker
#
#                                               altLabels hiddenLabels  \
# 2899  community home care worker\nhome care assistan...          NaN
#
#         status              modifiedDate  \
# 2899  released  2022-12-22T15:04:36.328Z
#
#                                 regulatedProfessionNote scopeNote definition  \
# 2899  http://data.europa.eu/esco/regulated-professio...       NaN        NaN
#
#                                                inScheme  \
# 2899  http://data.europa.eu/esco/concept-scheme/memb...
#
#                                             description      code
# 2899  Care home workers provide domiciliary services...  3412.4.2

# %%
df_occ[df_occ.preferredLabel.str.lower() == "care at home worker"]
# Out:
# Empty DataFrame
# Columns: [conceptType, conceptUri, iscoGroup, preferredLabel, altLabels, hiddenLabels, status, modifiedDate, regulatedProfessionNote, scopeNote, definition, inScheme, description, code]
# Index: []

# %%
# Apply replacements to all columns in the dataset beginning with ESCO_title
for i in range(16):
    dataset['train'] = dataset['train'].map(lambda example: replace_esco_titles(example, i))
    dataset['validation'] = dataset['validation'].map(lambda example: replace_esco_titles(example, i))
    dataset['test'] = dataset['test'].map(lambda example: replace_esco_titles(example, i))

# %%
dataset['train']
# Out:
# Dataset({
# ...

# %%
# Extract all title_k, description_k pairs from the training dataset
all_title_description_pairs = []

for example in dataset['train']:
    num_experiences = example['number_of_experiences']
    for k in range(num_experiences):
        title = example.get(f'title_{k}')
        description = example.get(f'description_{k}')
        esco = example.get(f'ESCO_uri_{k}')
        split = 'train'
        all_title_description_pairs.append([title, description, esco, split])

print(f"Total title-description pairs extracted: {len(all_title_description_pairs)}")
print("\nFirst 5 pairs:")
for i, l in enumerate(all_title_description_pairs[:5]):
    print(f"{i+1}. Title: {l[0]}")
    print(f"   Description: {l[1][:100]}...")
    print(f"   ESCO ID: {l[2][:100]}...")
    print()
# Out:
# Total title-description pairs extracted: 7912
#
# First 5 pairs:
# 1. Title: Line Cook
#    Description: - Prepped food for the line and cooked appetizers, soups, sandwiches, and fried foods
# - Detail clean...
#    ESCO ID: http://data.europa.eu/esco/occupation/90f75f67-495d-49fa-ab57-2f320e251d7e...
#
# 2. Title: Line Cook
#    Description: - Prepared food for the line and cooked a variety of dishes
# - Created daily specials and closed the ...
#    ESCO ID: http://data.europa.eu/esco/occupation/90f75f67-495d-49fa-ab57-2f320e251d7e...
#
# 3. Title: Line Chef
#    Description: - Prepared food for the kitchen and created specials for the dinner and lunch menu
# - Cooked food for...
#    ESCO ID: http://data.europa.eu/esco/occupation/01484951-15e6-4b88-a20f-1201868d36a0...
#
# 4. Title: Executive Chef
#    Description: - Promoted from rounds chef to sous chef in 2009, and then to executive chef in 2011
# - Implemented f...
# ...

# %%
for example in dataset['validation']:
    num_experiences = example['number_of_experiences']
    for k in range(num_experiences):
        title = example.get(f'title_{k}')
        description = example.get(f'description_{k}')
        esco = example.get(f'ESCO_uri_{k}')
        split='val'
        all_title_description_pairs.append([title, description, esco, split])

# %%
for example in dataset['test']:
    num_experiences = example['number_of_experiences']
    for k in range(num_experiences):
        title = example.get(f'title_{k}')
        description = example.get(f'description_{k}')
        esco = example.get(f'ESCO_uri_{k}')
        split='test'
        all_title_description_pairs.append([title, description, esco,split])

# %%
len(all_title_description_pairs)
# Out:
# 9919

# %%
all_title_description_pairs[0]
# Out:
# ['Line Cook',
#  '- Prepped food for the line and cooked appetizers, soups, sandwiches, and fried foods\n- Detail cleaned the kitchen\n- Developed strong communication skills in a fast-paced kitchen environment',
#  'http://data.europa.eu/esco/occupation/90f75f67-495d-49fa-ab57-2f320e251d7e',
#  'train']

# %%
# Get unique pairs only, filtering out NaN descriptions
unique_pairs = set()
for title, description, esco_id, split in all_title_description_pairs:
    if pd.notna(description):  # Filter out NaN descriptions
        unique_pairs.add((title, description, esco_id, split))
    else:
        print('hey')
        description = 'na'
        unique_pairs.add((title, description, esco_id, split))

print(f"Total unique title-description-esco pairs (excluding NaN descriptions): {len(unique_pairs)}")
# Out:
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# Total unique title-description-esco pairs (excluding NaN descriptions): 9885

# %%
# Get items where description is 'na'
na_items = [item for item in unique_pairs if item[1] == 'na']
print(f"Number of items with 'na' description: {len(na_items)}")
na_items[:5]  # Show first 5 items
# Out:
# Number of items with 'na' description: 8
# [('Key Hourly Manager',
#   'na',
#   'http://data.europa.eu/esco/occupation/b7744a45-a4ce-4037-b679-3d2377e17f31',
#   'train'),
#  ('Delivery Lead',
#   'na',
#   'http://data.europa.eu/esco/occupation/0c408028-c48f-4df8-ba5d-c3d3be15f5a2',
#   'train'),
#  ('Regional Training Coordinator and Residential Representative',
#   'na',
#   'http://data.europa.eu/esco/occupation/a14e96a7-6c4d-4d69-8c6f-7ccadf77bac5',
#   'val'),
#  ('Math Teacher',
#   'na',
#   'http://data.europa.eu/esco/occupation/f0e1cc13-48e0-4995-8699-ee43467bce0d',
#   'train'),
#  ('Assistant Supervisor/Head Bartender',
#   'na',
#   'http://data.europa.eu/esco/occupation/2f5e38a0-6578-4665-bdbd-e2ab505be140',
#   'train')]

# %%
unique_pairs
# Out:
# {('Manager, Partner Marketing',
#   'Directed partner relations and partner marketing during a hyper-growth period and led cross-divisional teams to onboard strategic partnerships with major media companies such as the National Football League, CBS Sportsline, ABC News, Bloomberg L.P., NBC, Reuters, Web M.D., and Business Week. Developed customized marketing campaigns each month for national media partners resulting in significant customer acquisition. Managed an $18M annual partner marketing budget and a staff of six.',
#   'http://data.europa.eu/esco/occupation/6fcf4638-e7c7-4978-9302-9a7b63a3d57c',
#   'train'),
#  ('Merchandiser, Sales',
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'raw_title', 'raw_description', 'esco_title',
#        'esco_description', 'esco_id', 'job_id'],
#       dtype='object')

# %%
# Create DataFrame from unique_pairs
unique_df = pd.DataFrame(list(unique_pairs), columns=['raw_title', 'raw_description', 'esco_id', 'split'])
unique_df
# Out:
#                                     raw_title  \
# 0                  Manager, Partner Marketing
# 1                         Merchandiser, Sales
# 2               Digital Merchandising Analyst
# 3                         Property Accountant
# 4      Electrical Power Production Apprentice
# ...                                       ...
# 9880                               Consultant
# 9881  Administrative Executive and Accountant
# 9882                        Apparel Associate
# 9883                       Associate Producer
# 9884                            Sales Advisor
#
#                                         raw_description  \
# 0     Directed partner relations and partner marketi...
# 1     Worked for Southern Wine & Spirits, a family o...
# 2     Report on sales trends and observations to inf...
# 3     Assisted the GM in financial forecasts and bud...
# 4     Installed, operated, and maintained 37 permane...
# ...                                                 ...
# ...

# %%
df_occ.columns
# Out:
# Index(['conceptType', 'conceptUri', 'iscoGroup', 'preferredLabel', 'altLabels',
#        'hiddenLabels', 'status', 'modifiedDate', 'regulatedProfessionNote',
#        'scopeNote', 'definition', 'inScheme', 'description', 'code',
#        'iscoGroup_1', 'iscoGroup_2', 'iscoGroup_3', 'iscoGroup_4'],
#       dtype='object')

# %%
df_occ.merge(unique_df.query('split == "test"'), left_on='conceptUri', right_on='esco_id', how='left').iscoGroup_1.value_counts().sort_index()
# Out:
# iscoGroup_1
# 0      22
# 1     533
# 2    1067
# 3     771
# 4     175
# 5     267
# 6      44
# 7     397
# 8     354
# 9      82
# Name: count, dtype: int64

# %%
df_occ.iscoGroup_1.unique()
# Out:
# array([2, 8, 7, 3, 5, 1, 6, 4, 9])

# %%
unique_df.groupby(['raw_title', 'raw_description']).esco_id.nunique().sort_values()
# Out:
# raw_title                                                     raw_description
# ...

# %%
# additional task here, you can skip
import pandas as pd

df_master_2 = pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/decorte_master_2.csv')

# %%
df_master_2.merge(
    unique_df, 
    left_on=['raw_title', 'raw_description', 'esco_id'],
    right_on=['raw_title', 'raw_description', 'esco_id'],
    how='left').drop(columns=['Unnamed: 0']).to_csv('/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/decorte_master_3.csv')

# %%
df_master_2.shape
# Out:
# (9885, 8)

# %%
df_master_2['l_raw_title'] = df_master_2.raw_title.apply(lambda x: x.lower())

df_master_2.drop_duplicates(subset='l_raw_title')
# Out:
#       Unnamed: 0                         raw_title  \
# 0              0                         Line Cook
# 1              1                         Line Chef
# 2              2                    Executive Chef
# 3              3        Banquet Cook 2( Lead Cook)
# 4              4                Kitchen Supervisor
# ...          ...                               ...
# 7924        7924  General Manager and Board Member
# 7925        7925       Intraday Operations Analyst
# 7927        7927        Workforce Specialist (WFM)
# 7928        7928             Sr. Workforce Manager
# 7929        7929        Workforce Planning Manager
#
#                                         raw_description  \
# 0     - Prepped food for the line and cooked appetiz...
# 1     - Prepared food for the kitchen and created sp...
# 2     - Promoted from rounds chef to sous chef in 20...
# 3     - Attended daily BEO meetings\n- Prepped and f...
# 4     - Oversaw the am shift\n- Part of a renovation...
# ...

# %%
df_aug_2 = pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/processed/augmentation/augmented_decorte_occupations_with_desc_2.csv')

# %%
df_test_only = df_master_2.merge(unique_df, left_on=['raw_title', 'raw_description', 'esco_id'], right_on=['raw_title', 'raw_description', 'esco_id']).query('split=="test"')

# %%
df_test_only.merge(df_occ[['iscoGroup','conceptUri']], left_on='esco_id', right_on='conceptUri', how='left').to_csv('/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/category_test_split_isco.csv')

# %%
import pandas as pd
df=pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/category_test_split_isco.csv')

# %%
df.shape
# Out:
# (1046, 12)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                   raw_title  \
# 0             0        6163                             Chef de Cuisine
# 1             1        6164                        Chef/General Manager
# 2             2        6165                              Executive Chef
# 3             3        6166  Lead Cook/Kitchen Trainer, Kitchen Manager
# 4             4        6167                                   Lead Cook
#
#                                      raw_description          esco_title  \
# 0  Worked with executive chef to develop and exec...           head chef
# 1  Developed food and beverage menu for a new fas...  restaurant manager
# 2  Co-ordinated and executed meals for various co...           head chef
# 3  - Cook and Prepare meals for our guest.\n- Res...                cook
# 4  - Put in product orders for the Restaurant.\n-...           head chef
#
#                                     esco_description  \
# ...

# %%
import numpy as np
unique_df['new_job_id'] = np.arange(1,len(unique_df)+1)

# %%
df.merge(unique_df, left_on=['raw_title', 'raw_description', 'esco_id'], right_on = ['raw_title', 'raw_description', 'esco_id'], how='left').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7930 entries, 0 to 7929
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7930 non-null   int64
#  1   raw_title         7930 non-null   object
#  2   raw_description   7922 non-null   object
#  3   esco_title        7930 non-null   object
#  4   esco_description  7928 non-null   object
#  5   esco_id           7930 non-null   object
#  6   job_id            7930 non-null   int64
#  7   new_job_id        7920 non-null   float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 495.8+ KB

# %%
df.merge(unique_df, left_on=['raw_title', 'raw_description', 'esco_id'], right_on = ['raw_title', 'raw_description', 'esco_id'], how='left').query('new_job_id.isna()')
# Out:
#       Unnamed: 0                                          raw_title  \
# 214          214                                           Med Tech
# 1266        1266                         Trainer, Bartender, Server
# 2082        2082                                   Accounting Clerk
# 4881        4881                                 Management Trainee
# 4882        4882                                      Delivery Lead
# 5384        5384                                 Key Hourly Manager
# 5385        5385                Assistant Supervisor/Head Bartender
# 5691        5691                                       Math Teacher
# 6464         301                                          Caregiver
# 7543         454  Regional Training Coordinator and Residential ...
#
#                                         raw_description  \
# 214   Promoted continuity of care by accurately and ...
# 1266                                                NaN
# ...

# %%
unique_df.query('raw_title == "Med Tech"')
# Out:
#      raw_title                                    raw_description  \
# 7954  Med Tech  Promoted continuity of care by accurately and ...
#
#                                                 esco_id  new_job_id
# 7954  http://data.europa.eu/esco/occupation/f4525ed8...        7955

# %%
# Note for tomorrow: So many values in unique df but not in master df. Extract wrong ones, apply augmentation on them, concat to master df, re-run everything!

# %%
df.query("esco_id == 'http://data.europa.eu/esco/occupation/81309031-dad2-4a7a-bde6-7f6e518f89ff'")
# Out:
#       Unnamed: 0  raw_title  \
# 214          214   Med Tech
# 6464         301  Caregiver
#
#                                         raw_description  \
# 214   Promoted continuity of care by accurately and ...
# 6464  - Assessed the need for, ordered, obtained, an...
#
#                         esco_title esco_description  \
# 214   residential care home worker              NaN
# 6464  residential care home worker              NaN
#
#                                                 esco_id  job_id
# 214   http://data.europa.eu/esco/occupation/81309031...     214
# 6464  http://data.europa.eu/esco/occupation/81309031...    6464

# %%
unique_df.query("esco_id == 'http://data.europa.eu/esco/occupation/f4525ed8-54eb-4a3b-90db-55cc01b0d9fd'")
# Out:
#                               raw_title  \
# 76                  Healthcare Provider
# 1032           Home Healthcare Provider
# 2877                          Caregiver
# 5733                Healthcare Provider
# 7904  Private Duty Home Healthcare Aide
# 7954                           Med Tech
# 9824                   Stay at home mom
#
#                                         raw_description  \
# 76            Provided healthcare for at-home patients.
# 1032  Provided home healthcare services, including a...
# 2877  - Assessed the need for, ordered, obtained, an...
# 5733  Through Manna, I provided care for a mentally ...
# 7904  Supported healthy nutrition by cooking meals a...
# 7954  Promoted continuity of care by accurately and ...
# 9824  Took a break from work to focus on being a sta...
#
#                                                 esco_id  new_job_id
# 76    http://data.europa.eu/esco/occupation/f4525ed8...          77
# ...

# %%
unique_df.shape
# Out:
# (9885, 4)

# %%
unique_df[['raw_title', 'raw_description']].drop_duplicates().shape
# Out:
# (9885, 2)

# %%
final_df = unique_df.merge(df_occ[['conceptUri', 'preferredLabel', 'description']], left_on='esco_id', right_on='conceptUri')

# %%
final_df.head()
# Out:
#                                  raw_title  \
# 0                Associate Fund Controller
# 1                     Online English Tutor
# 2  Assistant Director of Polar Expeditions
# 3                                Assistant
# 4              Product Designer (contract)
#
#                                      raw_description  \
# 0  Performed quarterly and annual close procedure...
# 1  - Analyzed student progress to adjust lesson p...
# 2  Handled sales and procurement of polar adventu...
# 3  Assisted directors, board of directors, and hu...
# 4  Worked with a creative team to develop ideas a...
#
#                                              esco_id  new_job_id  \
# 0  http://data.europa.eu/esco/occupation/e20eee17...           1
# 1  http://data.europa.eu/esco/occupation/59bce29f...           2
# 2  http://data.europa.eu/esco/occupation/6ce3c372...           3
# 3  http://data.europa.eu/esco/occupation/8cce40c1...           4
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'raw_title', 'raw_description', 'esco_title',
#        'esco_description', 'esco_id', 'job_id'],
#       dtype='object')

# %%
final_df = final_df.rename(
    columns={
        'preferredLabel':'esco_title',
        'description': 'esco_description'
    }
)[['raw_title', 'raw_description', 'esco_title', 'esco_description', 'esco_id', 'new_job_id']]

# %%
df.merge(final_df, left_on=['raw_title', 'raw_description', 'esco_id'], right_on=['raw_title', 'raw_description', 'esco_id'], how='left').sort_values('new_job_id')
# Out:
#       Unnamed: 0                                          raw_title  \
# 4469        4469                          Associate Fund Controller
# 5374        5374                               Online English Tutor
# 1070        1070            Assistant Director of Polar Expeditions
# 1065        1065                                          Assistant
# 4179        4179                        Product Designer (contract)
# ...          ...                                                ...
# 5384        5384                                 Key Hourly Manager
# 5385        5385                Assistant Supervisor/Head Bartender
# 5691        5691                                       Math Teacher
# 6464         301                                          Caregiver
# 7543         454  Regional Training Coordinator and Residential ...
#
#                                         raw_description  \
# 4469  Performed quarterly and annual close procedure...
# ...

# %%
replacements_title = {
        'ICT security engineer': 'cyber incident responder',
        'ict security engineer': 'cyber incident responder',
        'care at home worker': 'care home worker',
        'residential care home worker': 'care home worker',
        'ICT security manager': 'cybersecurity risk manager',
        'ict security manager': 'cybersecurity risk manager',
        'care at home worker': 'care home worker',
        'handyman': 'handyperson',
        'corporate banking manager': 'corporate banking adviser',
    }

replacements_uri = {
        'http://data.europa.eu/esco/occupation/81309031-dad2-4a7a-bde6-7f6e518f89ff': 
        'http://data.europa.eu/esco/occupation/f4525ed8-54eb-4a3b-90db-55cc01b0d9fd'
    }

# %%
df_adj = df.copy()

df_adj['esco_title'] = df_adj['esco_title'].replace(replacements_title)
df_adj['esco_id'] = df_adj['esco_id'].replace(replacements_uri)

# %%
df_adj['raw_description'].fillna('na', inplace=True)
# Out:
# /tmp/ipykernel_722487/1315433252.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_adj['raw_description'].fillna('na', inplace=True)

# %%
df.merge(final_df, left_on=['raw_title', 'raw_description', 'esco_id'], right_on=['raw_title', 'raw_description', 'esco_id'], how='left').sort_values('new_job_id').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7930 entries, 4469 to 7543
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          7930 non-null   int64
#  1   raw_title           7930 non-null   object
#  2   raw_description     7922 non-null   object
#  3   esco_title_x        7930 non-null   object
#  4   esco_description_x  7928 non-null   object
#  5   esco_id             7930 non-null   object
#  6   job_id              7930 non-null   int64
#  7   esco_title_y        7920 non-null   object
#  8   esco_description_y  7920 non-null   object
#  9   new_job_id          7920 non-null   float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 681.5+ KB

# %%
df_adj.merge(final_df, left_on=['raw_title', 'raw_description', 'esco_id'], right_on=['raw_title', 'raw_description', 'esco_id'], how='left').sort_values('new_job_id').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7930 entries, 4469 to 4254
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          7930 non-null   int64
#  1   raw_title           7930 non-null   object
#  2   raw_description     7930 non-null   object
#  3   esco_title_x        7930 non-null   object
#  4   esco_description_x  7928 non-null   object
#  5   esco_id             7930 non-null   object
#  6   job_id              7930 non-null   int64
#  7   esco_title_y        7930 non-null   object
#  8   esco_description_y  7930 non-null   object
#  9   new_job_id          7930 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 681.5+ KB

# %%
final_with_old = df_adj.merge(final_df, left_on=['raw_title', 'raw_description', 'esco_id'], right_on=['raw_title', 'raw_description', 'esco_id'], how='right').sort_values('job_id')
final_with_old['new_job_id'] = np.arange(final_with_old.shape[0])

# %%
final_with_old.query('esco_title_x != esco_title_y').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1955 entries, 11 to 9883
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          0 non-null      float64
#  1   raw_title           1955 non-null   object
#  2   raw_description     1955 non-null   object
#  3   esco_title_x        0 non-null      object
#  4   esco_description_x  0 non-null      object
#  5   esco_id             1955 non-null   object
#  6   job_id              0 non-null      float64
#  7   esco_title_y        1955 non-null   object
#  8   esco_description_y  1955 non-null   object
#  9   new_job_id          1955 non-null   int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 168.0+ KB

# %%
final_with_old.query('esco_description_x != esco_description_y')
# Out:
#       Unnamed: 0                   raw_title  \
# 7954       214.0                    Med Tech
# 2877       301.0                   Caregiver
# 11           NaN                  Controller
# 12           NaN            Office Assistant
# 18           NaN           Software Engineer
# ...          ...                         ...
# 9865         NaN             General Manager
# 9866         NaN           Senior Accountant
# 9867         NaN  Human Resources Specialist
# 9874         NaN                       Tutor
# 9883         NaN                  Accountant
#
#                                         raw_description      esco_title_x  \
# 7954  Promoted continuity of care by accurately and ...  care home worker
# 2877  - Assessed the need for, ordered, obtained, an...  care home worker
# 11    Managed the financial health of a provider of ...               NaN
# 12    Greeted persons entering establishment, determ...               NaN
# ...

# %%
#final_with_old=final_with_old.drop(columns=['Unnamed: 0', 'esco_title_x', 'esco_description_x'])
#final_with_old.job_id = final_with_old.job_id.astype(int)
final_with_old.rename(
    columns={
        'esco_title_y':'esco_title',
        'esco_description_y':'esco_description'
    },
    inplace=True
)

# %%
final_with_old.query("raw_title.str.contains('Delivery')")
# Out:
#       Unnamed: 0                                          raw_title  \
# 861        106.0                   Warehouse Worker/Delivery Driver
# 2018      1281.0                                Bay Delivery Driver
# 7839      1516.0   Regional Manager, Professional Services Delivery
# 6637      1788.0                                    Delivery Driver
# 299       2164.0                       Service Delivery Coordinator
# 8960      3211.0  Team Leader / Service Delivery Coordinator / S...
# 8496      3908.0                                    Delivery Driver
# 3135      4329.0                             CSR/Delivery/Warehouse
# 7271      4882.0                                      Delivery Lead
# 202       4885.0                Online Advertising Delivery Manager
# 108       5606.0  Healthcare Documentation Services Delivery Man...
# 4093      5990.0               Business Systems Delivery Consultant
# 3548       554.0                                    Delivery Driver
# ...

# %%
# Augmented data

df_aug = pd.read_csv(r'../data/processed/augmentation/augmented_decorte_occupations.csv')
df_aug_desc =  pd.read_csv(r'../data/processed/augmentation/augmented_decorte_occupations_with_desc.csv')

# %%
df_aug_desc.head()
# Out:
#    job_id                   raw_title  \
# 0       0                   Line Cook
# 1       1                   Line Chef
# 2       2              Executive Chef
# 3       3  Banquet Cook 2( Lead Cook)
# 4       4          Kitchen Supervisor
#
#                                      raw_description          esco_title  \
# 0  - Prepped food for the line and cooked appetiz...                cook
# 1  - Prepared food for the kitchen and created sp...           head chef
# 2  - Promoted from rounds chef to sous chef in 20...           head chef
# 3  - Attended daily BEO meetings\n- Prepped and f...                cook
# 4  - Oversaw the am shift\n- Part of a renovation...  restaurant manager
#
#                                     esco_description  \
# 0  Cooks are culinary operatives who are able to ...
# 1  Head chefs manage the kitchen to oversee the p...
# 2  Head chefs manage the kitchen to oversee the p...
# 3  Cooks are culinary operatives who are able to ...
# ...

# %%
df_aug_desc.merge(final_with_old, left_on='job_id', right_on='job_id', how='left').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7930 entries, 0 to 7929
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_id              7930 non-null   int64
#  1   raw_title_x         7930 non-null   object
#  2   raw_description_x   7922 non-null   object
#  3   esco_title_x        7930 non-null   object
#  4   esco_description_x  7928 non-null   object
#  5   esco_id_x           7930 non-null   object
#  6   skill_brief         7930 non-null   object
#  7   Unnamed: 0          7930 non-null   float64
#  8   raw_title_y         7930 non-null   object
#  9   raw_description_y   7930 non-null   object
#  10  esco_title_x        7930 non-null   object
#  11  esco_description_x  7928 non-null   object
#  12  esco_id_y           7930 non-null   object
#  13  esco_title_y        7930 non-null   object
#  14  esco_description_y  7930 non-null   object
# ...

# %%
df_aug_desc.merge(final_with_old, left_on='job_id', right_on='job_id', how='right').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9885 entries, 0 to 9884
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_id              7930 non-null   float64
#  1   raw_title_x         7930 non-null   object
#  2   raw_description_x   7922 non-null   object
#  3   esco_title_x        7930 non-null   object
#  4   esco_description_x  7928 non-null   object
#  5   esco_id_x           7930 non-null   object
#  6   skill_brief         7930 non-null   object
#  7   Unnamed: 0          7930 non-null   float64
#  8   raw_title_y         9885 non-null   object
#  9   raw_description_y   9885 non-null   object
#  10  esco_title_x        7930 non-null   object
#  11  esco_description_x  7928 non-null   object
#  12  esco_id_y           9885 non-null   object
#  13  esco_title_y        9885 non-null   object
#  14  esco_description_y  9885 non-null   object
# ...

# %%
merged = df_aug_desc.merge(final_with_old, left_on='job_id', right_on='job_id', how='right')

# %%
merged[merged.job_id.isna()].rename(
    columns={
        'esco_id_y': 'esco_id',
        'esco_title_y': 'esco_title',
        'esco_description_y': 'esco_description',
        'raw_title_y': 'raw_title',
        'raw_description_y': 'raw_description'
    }
)[[ 'raw_title', 'raw_description', 'esco_title',
       'esco_description', 'esco_id', 'new_job_id']].rename(columns={'new_job_id':'job_id'}).to_csv('/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/decorte_missing.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                   raw_title  \
# 0           0                   Line Cook
# 1           1                   Line Chef
# 2           2              Executive Chef
# 3           3  Banquet Cook 2( Lead Cook)
# 4           4          Kitchen Supervisor
#
#                                      raw_description          esco_title  \
# 0  - Prepped food for the line and cooked appetiz...                cook
# 1  - Prepared food for the kitchen and created sp...           head chef
# 2  - Promoted from rounds chef to sous chef in 20...           head chef
# 3  - Attended daily BEO meetings\n- Prepped and f...                cook
# 4  - Oversaw the am shift\n- Part of a renovation...  restaurant manager
#
#                                     esco_description  \
# 0  Cooks are culinary operatives who are able to ...
# 1  Head chefs manage the kitchen to oversee the p...
# 2  Head chefs manage the kitchen to oversee the p...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'raw_title', 'raw_description', 'esco_title',
#        'esco_description', 'esco_id', 'job_id'],
#       dtype='object')

# %%
# Importing new augmented data
df_recent = pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/processed/augmentation/augmented_decorte_missing_occupations.csv')

# %%
df_recent.head()
# Out:
#    Unnamed: 0          raw_title  \
# 0        7930         Controller
# 1        7931   Office Assistant
# 2        7932  Software Engineer
# 3        7933  Software Engineer
# 4        7934    History Teacher
#
#                                      raw_description  \
# 0  Managed the financial health of a provider of ...
# 1  Greeted persons entering establishment, determ...
# 2  - Designed and developed an application to mig...
# 3  Worked at Star Media and DPS. Developed video ...
# 4  Fifth grade social studies teacher at Thunderb...
#
#                  esco_title  \
# 0      financial controller
# 1  administrative assistant
# 2        software developer
# 3        software developer
# 4  secondary school teacher
#
#                                     esco_description  \
# 0  Financial controllers handle all tasks related...
# 1  Administrative assistants provide administrati...
# 2  Software developers implement or program all k...
# ...

# %%
df_aug.head()
# Out:
#    job_id                   raw_title  \
# 0       0                   Line Cook
# 1       1                   Line Chef
# 2       2              Executive Chef
# 3       3  Banquet Cook 2( Lead Cook)
# 4       4          Kitchen Supervisor
#
#                                      raw_description          esco_title  \
# 0  - Prepped food for the line and cooked appetiz...                cook
# 1  - Prepared food for the kitchen and created sp...           head chef
# 2  - Promoted from rounds chef to sous chef in 20...           head chef
# 3  - Attended daily BEO meetings\n- Prepped and f...                cook
# 4  - Oversaw the am shift\n- Part of a renovation...  restaurant manager
#
#                                     esco_description  \
# 0  Cooks are culinary operatives who are able to ...
# 1  Head chefs manage the kitchen to oversee the p...
# 2  Head chefs manage the kitchen to oversee the p...
# 3  Cooks are culinary operatives who are able to ...
# ...

# %%
df_aug_desc.head()
# Out:
#    job_id                   raw_title  \
# 0       0                   Line Cook
# 1       1                   Line Chef
# 2       2              Executive Chef
# 3       3  Banquet Cook 2( Lead Cook)
# 4       4          Kitchen Supervisor
#
#                                      raw_description          esco_title  \
# 0  - Prepped food for the line and cooked appetiz...                cook
# 1  - Prepared food for the kitchen and created sp...           head chef
# 2  - Promoted from rounds chef to sous chef in 20...           head chef
# 3  - Attended daily BEO meetings\n- Prepped and f...                cook
# 4  - Oversaw the am shift\n- Part of a renovation...  restaurant manager
#
#                                     esco_description  \
# 0  Cooks are culinary operatives who are able to ...
# 1  Head chefs manage the kitchen to oversee the p...
# 2  Head chefs manage the kitchen to oversee the p...
# 3  Cooks are culinary operatives who are able to ...
# ...

# %%
df_aug.iloc[1,-1]
# Out:
# 'A Line Chef needs strong cooking skills, the ability to work efficiently in a fast-paced kitchen environment, and good communication skills to coordinate with other kitchen staff.'

# %%
df_aug_desc.iloc[1,-1]
# Out:
# 'Skills needed for a Line Chef role include proficiency in cooking techniques, ability to work efficiently under pressure, strong attention to detail, leadership skills to train new cooks, and a thorough understanding of food preparation and recipe development.'

# %%
ind = 0

print(f'Aug: {df_aug.iloc[ind,-1]}')
print(f'AugDesc: {df_aug_desc.iloc[ind,-1]}')
# Out:
# Aug: A Line Cook needs to have strong culinary skills, including knife skills, cooking techniques, and knowledge of food safety protocols. They should also be able to work efficiently in a fast-paced kitchen environment and collaborate well with the rest of the kitchen team.
# AugDesc: Skills needed for a Line Cook role include culinary techniques, food preparation, attention to detail in cleaning, and effective communication in a high-pressure kitchen setting.

# %%
df_recent.head()
# Out:
#    Unnamed: 0          raw_title  \
# 0        7930         Controller
# 1        7931   Office Assistant
# 2        7932  Software Engineer
# 3        7933  Software Engineer
# 4        7934    History Teacher
#
#                                      raw_description  \
# 0  Managed the financial health of a provider of ...
# 1  Greeted persons entering establishment, determ...
# 2  - Designed and developed an application to mig...
# 3  Worked at Star Media and DPS. Developed video ...
# 4  Fifth grade social studies teacher at Thunderb...
#
#                  esco_title  \
# 0      financial controller
# 1  administrative assistant
# 2        software developer
# 3        software developer
# 4  secondary school teacher
#
#                                     esco_description  \
# 0  Financial controllers handle all tasks related...
# 1  Administrative assistants provide administrati...
# 2  Software developers implement or program all k...
# ...

# %%
df_recent = df_recent[['job_id', 'raw_title', 'raw_description', 'esco_title',
       'esco_description', 'esco_id', 'skill_brief']]

# %%
df_aug_desc.head()
# Out:
#    job_id                   raw_title  \
# 0       0                   Line Cook
# 1       1                   Line Chef
# 2       2              Executive Chef
# 3       3  Banquet Cook 2( Lead Cook)
# 4       4          Kitchen Supervisor
#
#                                      raw_description          esco_title  \
# 0  - Prepped food for the line and cooked appetiz...                cook
# 1  - Prepared food for the kitchen and created sp...           head chef
# 2  - Promoted from rounds chef to sous chef in 20...           head chef
# 3  - Attended daily BEO meetings\n- Prepped and f...                cook
# 4  - Oversaw the am shift\n- Part of a renovation...  restaurant manager
#
#                                     esco_description  \
# 0  Cooks are culinary operatives who are able to ...
# 1  Head chefs manage the kitchen to oversee the p...
# 2  Head chefs manage the kitchen to oversee the p...
# 3  Cooks are culinary operatives who are able to ...
# ...

# %%
df_recent.head()
# Out:
#    job_id          raw_title  \
# 0    7930         Controller
# 1    7931   Office Assistant
# 2    7932  Software Engineer
# 3    7933  Software Engineer
# 4    7934    History Teacher
#
#                                      raw_description  \
# 0  Managed the financial health of a provider of ...
# 1  Greeted persons entering establishment, determ...
# 2  - Designed and developed an application to mig...
# 3  Worked at Star Media and DPS. Developed video ...
# 4  Fifth grade social studies teacher at Thunderb...
#
#                  esco_title  \
# 0      financial controller
# 1  administrative assistant
# 2        software developer
# 3        software developer
# 4  secondary school teacher
#
#                                     esco_description  \
# 0  Financial controllers handle all tasks related...
# 1  Administrative assistants provide administrati...
# 2  Software developers implement or program all k...
# 3  Software developers implement or program all k...
# ...

# %%
df_aug_desc_new = pd.concat([df_aug_desc, df_recent])

# %%
merged.rename(
    columns={
        'esco_id_y': 'esco_id',
        'esco_title_y': 'esco_title',
        'esco_description_y': 'esco_description',
        'raw_title_y': 'raw_title',
        'raw_description_y': 'raw_description'
    }
)[[ 'raw_title', 'raw_description', 'esco_title',
       'esco_description', 'esco_id', 'new_job_id']].rename(columns={'new_job_id':'job_id'}).merge(df_aug_desc_new[['job_id', 'skill_brief']]).to_csv('../data/processed/augmentation/augmented_decorte_occupations_with_desc_2.csv')

# %%
merged.rename(
    columns={
        'esco_id_y': 'esco_id',
        'esco_title_y': 'esco_title',
        'esco_description_y': 'esco_description',
        'raw_title_y': 'raw_title',
        'raw_description_y': 'raw_description'
    }
)[[ 'raw_title', 'raw_description', 'esco_title',
       'esco_description', 'esco_id', 'new_job_id']].rename(columns={'new_job_id':'job_id'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 merged.rename(
#       2     columns={
#       3         'esco_id_y': 'esco_id',
#       4         'esco_title_y': 'esco_title',
#       5         'esco_description_y': 'esco_description',
#       6         'raw_title_y': 'raw_title',
#       7         'raw_description_y': 'raw_description'
#       8     }
#       9 )[[ 'raw_title', 'raw_description', 'esco_title',
#      10        'esco_description', 'esco_id', 'new_job_id']].rename(columns={'new_job_id':'job_id'})
#
# NameError: name 'merged' is not defined

# %%
import pandas as pd

df_new = pd.read_csv('../data/processed/augmentation/augmented_decorte_occupations_with_desc_2.csv')

# %%
df_new.head()
# Out:
#    Unnamed: 0                   raw_title  \
# 0           0                   Line Cook
# 1           1                   Line Chef
# 2           2              Executive Chef
# 3           3  Banquet Cook 2( Lead Cook)
# 4           4          Kitchen Supervisor
#
#                                      raw_description          esco_title  \
# 0  - Prepped food for the line and cooked appetiz...                cook
# 1  - Prepared food for the kitchen and created sp...           head chef
# 2  - Promoted from rounds chef to sous chef in 20...           head chef
# 3  - Attended daily BEO meetings\n- Prepped and f...                cook
# 4  - Oversaw the am shift\n- Part of a renovation...  restaurant manager
#
#                                     esco_description  \
# 0  Cooks are culinary operatives who are able to ...
# 1  Head chefs manage the kitchen to oversee the p...
# 2  Head chefs manage the kitchen to oversee the p...
# ...

# %%
df_new.shape
# Out:
# (9885, 8)

# %%
df_new.drop(columns=['Unnamed: 0']).to_csv('../data/title_pairs_desc//decorte_master_2.csv')

# %%
df_new.query('esco_id == "http://data.europa.eu/esco/occupation/f4525ed8-54eb-4a3b-90db-55cc01b0d9fd"')
# Out:
#       Unnamed: 0                          raw_title  \
# 214          214                           Med Tech
# 5419        5419           Home Healthcare Provider
# 5476        5476  Private Duty Home Healthcare Aide
# 5500        5500                Healthcare Provider
# 6464        6464                          Caregiver
# 6787        6787                   Stay at home mom
# 7944        7944                Healthcare Provider
#
#                                         raw_description        esco_title  \
# 214   Promoted continuity of care by accurately and ...  care home worker
# 5419  Provided home healthcare services, including a...  care home worker
# 5476  Supported healthy nutrition by cooking meals a...  care home worker
# 5500  Through Manna, I provided care for a mentally ...  care home worker
# 6464  - Assessed the need for, ordered, obtained, an...  care home worker
# 6787  Took a break from work to focus on being a sta...  care home worker
# ...

# %%
import pandas as pd

df = pd.read_csv('/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/esco_datasets/occupationSkillRelations_en.csv')

# %%
df.head()
# Out:
#                                        occupationUri relationType  \
# 0  http://data.europa.eu/esco/occupation/00030d09...    essential
# 1  http://data.europa.eu/esco/occupation/00030d09...    essential
# 2  http://data.europa.eu/esco/occupation/00030d09...    essential
# 3  http://data.europa.eu/esco/occupation/00030d09...    essential
# 4  http://data.europa.eu/esco/occupation/00030d09...    essential
#
#           skillType                                           skillUri
# 0         knowledge  http://data.europa.eu/esco/skill/fed5b267-73fa...
# 1  skill/competence  http://data.europa.eu/esco/skill/05bc7677-5a64...
# 2  skill/competence  http://data.europa.eu/esco/skill/271a36a0-bc7a...
# 3  skill/competence  http://data.europa.eu/esco/skill/47ed1d37-971b...
# 4  skill/competence  http://data.europa.eu/esco/skill/591dd514-735b...

# %%
import numpy as np

# 'occupationUri' = occupation, 'skillUri' = skill
# Calculate the IDF (Inverse Document Frequency) for each skill (skillUri) according to: 
# idf(skill) = log(N / df), where N = total number of unique occupations, 
# df = number of unique occupations that have this skill

N = df['occupationUri'].nunique()
skill_df = df.groupby('skillUri')['occupationUri'].nunique().reset_index(name='occ_count')
skill_df['idf'] = np.log(N / skill_df['occ_count'])

skill_df.head()
# Out:
#                                             skillUri  occ_count       idf
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...          4  6.632989
# 1  http://data.europa.eu/esco/skill/00064735-8fad...          1  8.019284
# 2  http://data.europa.eu/esco/skill/000709ed-2be5...         30  4.618086
# 3  http://data.europa.eu/esco/skill/0007bdc2-dd15...         11  5.621389
# 4  http://data.europa.eu/esco/skill/00090cc1-1f27...          2  7.326137

# %%
import pandas as pd

df_1 = pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/processed/augmentation/augmented_esco_occupations_with_expanded_alts.csv')
df_2 = pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/processed/augmentation/augmented_esco_occupations_expanded.csv')
df_3 = pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/processed/augmentation/augmented_esco_occupations.csv')

# %%
df_1.shape
# Out:
# (33440, 5)

# %%
df_2.shape
# Out:
# (30401, 8)

# %%
df_3.shape
# Out:
# (3039, 2)

# %%
# additional task here, you can skip
import pandas as pd

df_master_2 = pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/decorte_master_3.csv')

# %%
df_master_2.split.value_counts()
# Out:
# split
# train    7882
# test     1046
# val       957
# Name: count, dtype: int64

# %%
6905 + 1022
# Out:
# 7927

# %%
6905 + 1022 + 821
# Out:
# 8748
