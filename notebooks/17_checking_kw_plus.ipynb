# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # KW CP

# %%
df = pd.read_csv(r'/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/karrierewege_plus_cp_master_3.csv')

# %%
df_ex = pd.read_csv(r'../data/title_pairs_desc/category_test_split_isco.csv')

# %%
df_ex.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'raw_title', 'raw_description',
#        'esco_title', 'esco_description', 'esco_id', 'job_id', 'skill_brief',
#        'split', 'iscoGroup', 'conceptUri'],
#       dtype='object')

# %%
df_ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1046 entries, 0 to 1045
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0.1      1046 non-null   int64
#  1   Unnamed: 0        1046 non-null   int64
#  2   raw_title         1046 non-null   object
#  3   raw_description   1046 non-null   object
#  4   esco_title        1046 non-null   object
#  5   esco_description  1046 non-null   object
#  6   esco_id           1046 non-null   object
#  7   job_id            1046 non-null   int64
#  8   skill_brief       1046 non-null   object
#  9   split             1046 non-null   object
#  10  iscoGroup         1046 non-null   int64
#  11  conceptUri        1046 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 98.2+ KB

# %%
df.head()
# Out:
#    Unnamed: 0       raw_title  \
# 0           0     Housekeeper
# 1           1     Housekeeper
# 2           2     Housekeeper
# 3           3     Housekeeper
# 4           4  Grounds Worker
#
#                                      raw_description  \
# 0  Responsible for maintaining the cleanliness an...
# 1  Assists in the upkeep and maintenance of a hom...
# 2  Ensures the overall tidiness and hygiene of a ...
# 3  Provides domestic assistance to homeowners by ...
# 4  Maintains the upkeep of outdoor spaces by perf...
#
#                                        occupationUri    preferredLabel
# 0  http://data.europa.eu/esco/occupation/cbad55a4...  domestic cleaner
# 1  http://data.europa.eu/esco/occupation/cbad55a4...  domestic cleaner
# 2  http://data.europa.eu/esco/occupation/cbad55a4...  domestic cleaner
# 3  http://data.europa.eu/esco/occupation/cbad55a4...  domestic cleaner
# 4  http://data.europa.eu/esco/occupation/a10eb17a...   garden labourer

# %%
df_occ = pd.read_csv('../data/esco_datasets/occupations_en.csv')

# %%
df.query('split == "test"').merge(df_occ[['iscoGroup','conceptUri']], left_on='esco_id', right_on='conceptUri', how='left').to_csv(
    '/dss/dsshome1/02/ra95kix2/thesis/skills4cpp/data/title_pairs_desc/category_test_split_isco_kw_cp.csv')
